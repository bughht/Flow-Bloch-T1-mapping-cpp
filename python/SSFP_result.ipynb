# %%
import os
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from load_cppimg import load_img,load_kspace
import scipy.fft as sfft
import re
# %matplotlib inline

# path = '../exp_result_slow_1500_5x5/'
# path = '../exp_result_ssfp_fast/'
# path = '../experiments/exp_ssfp_gz/'
path = '../experiments/exp_MOLLI_0_4/'
exp_folders = [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))]
exp_folders.sort(key=lambda x: int(re.search(r'\d+', x).group()))
print("\n".join(exp_folders))
# Out:
# ID0_Speed_min0.0_max0.9696969696969697
# ID0_Speed_min0.0_max1.2972972972972974
# ID0_Speed_min0.0_max1.9591836734693877
# ID1_Speed_min2.0408163265306123_max4.0

# %%
for exp in exp_folders:
    
    MOLLI_readout_img=[]
    for i in range(1):
        MOLLI_readout_img.append(load_img(os.path.join(path, exp),i))
    MOLLI_readout_img=np.asarray(MOLLI_readout_img)
    plt.figure(figsize=(18,7))
    print(exp)
    for i in range(1):
        # plt.subplot(2, 4, i+1)
        plt.imshow(MOLLI_readout_img[i])
        # plt.imshow(sfft.fftshift(MOLLI_readout_img[i]))
        
        # plt.imshow(np.abs(np.fft.ifft2(MOLLI_readout_img[i])))
        # plt.imshow(np.abs(sfft.fftshift(sfft.fft2(MOLLI_readout_img[i]))))
        plt.colorbar(shrink=0.9)
    plt.show()
# Out:
# ID0_Speed_min0.0_max0.9696969696969697
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ae9cc22bf72a> in <module>
#       3     MOLLI_readout_img=[]
#       4     for i in range(1):
# ----> 5         MOLLI_readout_img.append(load_img(os.path.join(path, exp),i))
#       6     MOLLI_readout_img=np.asarray(MOLLI_readout_img)
#       7     plt.figure(figsize=(18,7))
#
# /data/honght/Flow-Bloch-T1-mapping-cpp/python/load_cppimg.py in load_img(path, id)
#       9 def load_img(path, id):
#      10     path_full = os.path.join(path, "Spatial" + str(id) + ".bin")
# ---> 11     with open(path_full, "rb") as f:
#      12         data = yaml.round_trip_load(f)["mat"]
#      13     return np.asarray(data["data"]).reshape(data["rows"], data["cols"])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../experiments/exp_MOLLI_0_4/ID0_Speed_min0.0_max1.2972972972972974/Spatial0.bin'

# %%
x=5
y=5
k=64
radius=18.0/256*64
dx=-1
dy=-1
mask = np.ones((k,k),dtype=bool)
for i in range(x):
    for j in range(y):
        for m in range(k):
            for n in range(k):
                if (m-(i+0.5)*k/x-dx)**2 + (n-(j+0.5)*k/y-dy)**2 < radius**2:
                    mask[m,n] = 0
plt.figure(figsize=(18,7))
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.imshow(np.ma.masked_array(MOLLI_readout_img[i] , mask=mask))
    plt.colorbar(shrink=0.9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-cb8ffc10e5e7> in <module>
#      15 for i in range(8):
#      16     plt.subplot(2,4,i+1)
# ---> 17     plt.imshow(np.ma.masked_array(MOLLI_readout_img[i] , mask=mask))
#      18     plt.colorbar(shrink=0.9)
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
